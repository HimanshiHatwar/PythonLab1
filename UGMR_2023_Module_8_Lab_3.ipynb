# %% [markdown]
# <a href="https://colab.research.google.com/github/HimanshiHatwar/PythonLab1/blob/main/UGMR_2023_Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-02 10:07:08--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  61.9MB/s    in 1.1s
#
# 2024-04-02 10:07:13 (61.9 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 32163  1604.06602v6  Many real-world clustering problems are plague...    cs
# 31788   1004.2316v2  In regular statistical models, the leave-one-o...    cs
# 18728   1111.0043v1  Reputation mechanisms offer an effective alter...    cs
# 20463  1602.07565v2  We consider partially observable Markov decisi...    cs
# 30101  1711.07011v1  This paper is aimed at creating extremely smal...    cs
# ...             ...                                                ...   ...
# 7697   1802.09031v1  Residual Networks (ResNets) have become state-...  stat
# 37074  1606.06434v1  Ontologies provide conceptual abstractions ove...    cs
# 11196   1412.7477v7  The pathwise coordinate optimization is one of...  stat
# 31758   0904.0814v1  This paper uses the notion of algorithmic stab...    cs
# 37718  1801.08829v1  Symbol emergence through a robot's own interac...    cs
#
#                                                    title  year  \
# 32163  Clustering with Missing Features: A Penalized ...  2016
# 31788  Asymptotic Equivalence of Bayes Cross Validati...  2010
# 18728  Obtaining Reliable Feedback for Sanctioning Re...  2011
# 20463  Stochastic Shortest Path with Energy Constrain...  2016
# 30101  MicroExpNet: An Extremely Small and Fast Model...  2017
# ...                                                  ...   ...
# 7697   Functional Gradient Boosting based on Residual...  2018
# 37074  The Schema Editor of OpenIoT for Semantic Sens...  2016
# 11196  Pathwise Coordinate Optimization for Sparse Le...  2014
# 31758  Stability Analysis and Learning Bounds for Tra...  2009
# 37718  Symbol Emergence in Cognitive Developmental Sy...  2018
#
#                                                 keywords
# 32163  [clustering, incomplete, characterized, instan...
# 31788  [statistical, validation, asymptotically, equi...
# 18728  [reputation, mechanisms, effective, alternativ...
# 20463  [partially, observable, processes, associated,...
# 30101  [extremely, convolutional, expression, recogni...
# ...                                                  ...
# 7697   [theoretical, understanding, attractive, viewp...
# 37074  [ontologies, conceptual, abstractions, harvest...
# 11196  [coordinate, optimization, important, computat...
# 31758  [algorithmic, stability, generalization, trans...
# 37718  [emergence, interactive, exploration, interven...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 32163    [clustering, incomplete, characterized, instan...
# 31788    [statistical, validation, asymptotically, equi...
# 18728    [reputation, mechanisms, effective, alternativ...
# 20463    [partially, observable, processes, associated,...
# 30101    [extremely, convolutional, expression, recogni...
#                                ...
# 35935    [algorithm, presented, traditional, universal,...
# 5506     [partition, projection, intrinsic, dimension, ...
# 7018     [knowledge, detection, currently, approaches, ...
# 13683    [stability, activation, operating, conditions,...
# 16482    [computation, similarity, important, foundatio...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8788 words.
# Out of those 4598 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2cc3fd69-38d4-4399-bd30-ddd92a37ce9f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2cc3fd69-38d4-4399-bd30-ddd92a37ce9f")) {                    Plotly.newPlot(                        "2cc3fd69-38d4-4399-bd30-ddd92a37ce9f",                        [{"x":["algorithm","conducted","traditional","preprocessing","hierarchical","dissimilarity","instances","experiments","characterized","applicable","iterations","converges","marginalization","unobserved","techniques","clustering","generally","agglomerative","extensive","complexity","imputation","benchmark","incomplete","extension","penalized","criterion","generalization","determined","therefore","expectation","statistical","theoretically","algebraic","asymptotic","information","threshold","structure","validation","hyperparameter","equivalence","optimization","geometrical","canonical","selection","asymptotically","different","established","equivalent","considering","transactions","establish","truthfully","equilibria","mechanisms","existence","alternative","important","decisions","reputation","explicitly","incentives","equilibrium","reporting","percentage","characterize","electronic","verification","obtaining","effective","mechanism","partially","processes","framework","represents","representation","objective","automated","contribution","observable","associated","developing","constraints","naturally","literature","constraint","automatically","experimentally","consumption","procedure","transition","stochastic","transitions","understandable","improvement","recognition","demonstrate","distillation","respectively","translation","invariance","especially","extremely","knowledge","convolutional","expression","performance","comparisons","compressed","parameters","prediction","predictive","underestimation","illustrate","systematic","considers","synthetic","quantification","regression","uncertainty","theoretical","achieving","iterative","depending","constructing","algorithms","convergence","sequentially","intelligently","distribution","efficiently","interaction","modalities","diversity","databases","interactions","supervised","approximation","relevance","unlabeled","efficient","effectiveness","heuristic","informative","classification","analyzing","irrelevant","challenge","extracted","classifier","scalability","interactive","classifying","incorporating","retrieval","appropriate","programming","imperative","languages","ancillary","extending","variables","discussed","conditions","conditional","independence","identifiability","sufficient","counterfactual","representing","procedures","automatic","reconstruction","evaluated","detectors","technology","identification","particles","distinguish","descriptor","reconstructing","characterizes","segmentation","presented","neighbourhood","projection","potential","excellent","amplitude","redundant","augmented","classical","concatenated","approaches","framelets","generalize","condition","behaviors","discovery","significant","unpooling"],"y":[830,77,158,24,107,11,110,639,30,57,33,24,4,11,356,138,60,6,152,217,5,218,34,62,6,43,111,44,162,27,138,34,16,24,678,35,345,52,7,29,336,10,23,158,10,729,44,58,74,2,59,2,9,54,31,80,355,56,3,71,2,13,11,13,50,27,27,41,230,104,49,106,534,52,344,146,92,75,27,107,58,144,58,117,82,189,48,24,119,38,141,18,3,146,384,554,7,86,108,23,130,42,329,360,44,861,31,27,268,229,66,0,72,27,38,142,14,116,75,178,89,84,51,33,576,121,22,4,203,161,88,31,54,66,75,187,119,35,40,383,199,51,38,489,57,13,150,114,159,33,37,51,45,104,94,121,6,78,1,30,112,55,133,109,17,1,62,2,61,35,187,110,138,30,55,87,9,28,27,25,14,198,176,1,47,148,21,6,23,45,86,3,427,1,51,46,32,53,237,1],"type":"bar"},{"x":["algorithm","conducted","traditional","preprocessing","hiera ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4598,), (4598, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Extended</span> <span style=''>Object</span> <span style=''>Tracking</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Introduction</span> <span style=''>Overview</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Applications</span> <br/><br/><span style=''>This</span> <span style=''>article</span> <span style=''>provides</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.38461538461538464);'>elaborate</span> <span style=''>overview</span> <span style=''>of</span> <span style=''>current</span> <span style=''>research</span> <span style=''>in</span> <span style=''>extended</span> <span style=''>object</span> <span style=''>tracking</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>clear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>definition</span> <span style=''>of</span> <span style=''>the</span> <span style=''>extended</span> <span style=''>object</span> <span style=''>tracking</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>discuss</span> <span style=''>its</span> <span style=''>delimitation</span> <span style=''>to</span> <span style=''>other</span> <span style=''>types</span> <span style=''>of</span> <span style=''>object</span> <span style=''>tracking</span> <span style=''>Next</span> <span style='background-color:rgba(0, 255, 0, 0.33150684931506846);'>different</span> <span style=''>aspects</span> <span style=''>of</span> <span style=''>extended</span> <span style=''>object</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modelling</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.41818181818181827);'>extensively</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discussed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Subsequently</span> <span style=''>we</span> <span style=''>give</span> <span style=''>a</span> <span style=''>tutorial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduction</span> <span style=''>to</span> <span style=''>two</span> <span style=''>basic</span> <span style=''>and</span> <span style=''>well</span> <span style=''>used</span> <span style=''>extended</span> <span style=''>object</span> <span style=''>tracking</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>the</span> <span style=''>random</span> <span style=''>matrix</span> <span style=''>approach</span> <span style=''>and</span> <span style=''>the</span> <span style=''>Kalman</span> <span style=''>filter</span> <span style=''>based</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>star</span> <span style=''>convex</span> <span style=''>shapes</span> <span style=''>The</span> <span style=''>next</span> <span style=''>part</span> <span style=''>treats</span> <span style=''>the</span> <span style=''>tracking</span> <span style=''>of</span> <span style=''>multiple</span> <span style=''>extended</span> <span style=''>objects</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>elaborates</span> <span style=''>how</span> <span style=''>the</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style=''>feasible</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>association</span> <span style='background-color:rgba(0, 255, 0, 0.40000000000000013);'>hypotheses</span> <span style=''>can</span> <span style=''>be</span> <span style=''>tackled</span> <span style=''>using</span> <span style=''>both</span> <span style=''>Random</span> <span style=''>Finite</span> <span style=''>Set</span> <span style=''>(RFS)</span> <span style=''>and</span> <span style=''>Non</span> <span style=''>RFS</span> <span style=''>multi</span> <span style=''>object</span> <span style=''>trackers</span> <span style=''>The</span> <span style=''>article</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Removing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>systematic</span> <span style=''>errors</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exoplanet</span> <span style=''>search</span> <span style=''>via</span> <span style=''>latent</span> <span style=''>causes</span> <br/><br/><span style=''>We</span> <span style=''>describe</span> <span style=''>a</span> <span style=''>method</span> <span style=''>for</span> <span style=''>removing</span> <span style=''>the</span> <span style=''>effect</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confounders</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruct</span> <span style=''>a</span> <span style=''>latent</span> <span style=''>quantity</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>The</span> <span style=''>method</span> <span style=''>referred</span> <span style=''>to</span> <span style=''>as</span> <span style=''>half</span> <span style=''>sibling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>is</span> <span style=''>inspired</span> <span style=''>by</span> <span style=''>recent</span> <span style=''>work</span> <span style=''>in</span> <span style=''>causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>using</span> <span style=''>additive</span> <span style=''>noise</span> <span style=''>models</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>justification</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>illustrate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>of</span> <span style=''>the</span> <span style=''>method</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>astronomy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Sketching</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Sequential</span> <span style=''>Change</span> <span style=''>Point</span> <span style='background-color:rgba(0, 255, 0, 0.46895074946466814);'>Detection</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequential</span> <span style=''>change</span> <span style=''>point</span> <span style='background-color:rgba(0, 255, 0, 0.46895074946466814);'>detection</span> <span style=''>using</span> <span style=''>sketches</span> <span style=''>(linear</span> <span style=''>projections)</span> <span style=''>of</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3903743315508022);'>dimensional</span> <span style=''>signal</span> <span style=''>vectors</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.4117647058823529);'>presenting</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sketching</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedures</span> <span style=''>that</span> <span style=''>are</span> <span style=''>derived</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalized</span> <span style='background-color:rgba(255, 0, 0, 0.44347826086956516);'>likelihood</span> <span style=''>ratio</span> <span style='background-color:rgba(255, 0, 0, 0.6000000000000001);'>statistic</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>both</span> <span style=''>fixed</span> <span style=''>and</span> <span style=''>time</span> <span style=''>varying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>projections</span> <span style=''>and</span> <span style=''>derive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>approximations</span> <span style=''>to</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fundamental</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>metrics</span> <span style=''>the</span> <span style=''>average</span> <span style=''>run</span> <span style=''>length</span> <span style=''>(ARL)</span> <span style=''>and</span> <span style=''>the</span> <span style=''>expected</span> <span style='background-color:rgba(0, 255, 0, 0.46895074946466814);'>detection</span> <span style=''>delay</span> <span style=''>(EDD)</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>approximations</span> <span style=''>are</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>be</span> <span style=''>highly</span> <span style=''>accurate</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3830508474576271);'>numerical</span> <span style='background-color:rgba(255, 0, 0, 0.3717948717948717);'>simulations</span> <span style=''>We</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterize</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>when</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>projection</span> <span style=''>is</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>projection</span> <span style=''>or</span> <span style=''>a</span> <span style=''>sparse</span> <span style=''>0</span> <span style=''>1</span> <span style=''>matrix</span> <span style=''>(in</span> <span style='background-color ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Top</span> <span style=''>k</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Multiclass</span> <span style=''>SVM</span> <br/><br/><span style=''>Class</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>ambiguity</span> <span style=''>is</span> <span style=''>typical</span> <span style=''>in</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>problems</span> <span style=''>with</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style=''>classes</span> <span style=''>When</span> <span style=''>classes</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminate</span> <span style=''>it</span> <span style=''>makes</span> <span style=''>sense</span> <span style=''>to</span> <span style=''>allow</span> <span style=''>k</span> <span style=''>guesses</span> <span style=''>and</span> <span style=''>evaluate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>top</span> <span style=''>k</span> <span style=''>error</span> <span style=''>instead</span> <span style=''>of</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>zero</span> <span style=''>one</span> <span style=''>loss</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>top</span> <span style=''>k</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multiclass</span> <span style=''>SVM</span> <span style=''>as</span> <span style=''>a</span> <span style=''>direct</span> <span style=''>method</span> <span style=''>to</span> <span style=''>optimize</span> <span style=''>for</span> <span style=''>top</span> <span style=''>k</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style=''>the</span> <span style=''>well</span> <span style=''>known</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multiclass</span> <span style=''>SVM</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>tight</span> <span style=''>convex</span> <span style=''>upper</span> <span style=''>bound</span> <span style=''>of</span> <span style=''>the</span> <span style=''>top</span> <span style=''>k</span> <span style=''>error</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>scheme</span> <span style=''>based</span> <span style=''>on</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style=''>onto</span> <span style=''>the</span> <span style=''>top</span> <span style=''>k</span> <span style=''>simplex</span> <span style=''>which</span> <span style=''>is</span> <span style=''>of</span> <span style=''>its</span> <span style=''>own</span> <span style=''>interest</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Experiments</span> <span style=''>on</span> <span style=''>five</span> <span style=''>datasets</span> <span style=''>show</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improvements</span> <span style=''>in</span> <span style=''>top</span> <span style=''>k</span> <span style=''>accuracy</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>various</span> <span style='background-color:rgba(255, 0, 0, 0.3); ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.06683345246604717)
# 	challenging (0.10257326661901359)
# 	information (0.24231593995711223)
# 	segmentation (0.07076483202287348)
# 	experimental (0.14403145103645462)
# 	architecture (0.09220872051465333)
# 	detection (0.12258756254467476)
# 	different (0.2605432451751251)
# 	convolutional (0.12866333095067906)
# 	recognition (0.13724088634739098)
#
# Some Statistics words are:
# 	algorithm (0.3811188811188811)
# 	stochastic (0.14085914085914086)
# 	estimation (0.17082917082917082)
# 	theoretical (0.16083916083916083)
# 	statistical (0.14735264735264736)
# 	distribution (0.17382617382617382)
# 	variables (0.14385614385614387)
# 	inference (0.2017982017982018)
# 	dimensional (0.19480519480519481)
# 	regression (0.18031968031968032)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cea26733-87e9-4615-8f5c-9d6f2087a41e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cea26733-87e9-4615-8f5c-9d6f2087a41e")) {                    Plotly.newPlot(                        "cea26733-87e9-4615-8f5c-9d6f2087a41e",                        [{"x":["algorithm","conducted","traditional","preprocessing","hierarchical","dissimilarity","instances","experiments","characterized","applicable","iterations","converges","marginalization","unobserved","techniques","clustering","generally","agglomerative","extensive","complexity","imputation","benchmark","incomplete","extension","penalized","criterion","generalization","determined","therefore","expectation","statistical","theoretically","algebraic","asymptotic","information","threshold","structure","validation","hyperparameter","equivalence","optimization","geometrical","canonical","selection","asymptotically","different","established","equivalent","considering","transactions","establish","truthfully","equilibria","mechanisms","existence","alternative","important","decisions","reputation","explicitly","incentives","equilibrium","reporting","percentage","characterize","electronic","verification","obtaining","effective","mechanism","partially","processes","framework","represents","representation","objective","automated","contribution","observable","associated","developing","constraints","naturally","literature","constraint","automatically","experimentally","consumption","procedure","transition","stochastic","transitions","understandable","improvement","recognition","demonstrate","distillation","respectively","translation","invariance","especially","extremely","knowledge","convolutional","expression","performance","comparisons","compressed","parameters","prediction","predictive","underestimation","illustrate","systematic","considers","synthetic","quantification","regression","uncertainty","theoretical","achieving","iterative","depending","constructing","algorithms","convergence","sequentially","intelligently","distribution","efficiently","interaction","modalities","diversity","databases","interactions","supervised","approximation","relevance","unlabeled","efficient","effectiveness","heuristic","informative","classification","analyzing","irrelevant","challenge","extracted","classifier","scalability","interactive","classifying","incorporating","retrieval","appropriate","programming","imperative","languages","ancillary","extending","variables","discussed","conditions","conditional","independence","identifiability","sufficient","counterfactual","representing","procedures","automatic","reconstruction","evaluated","detectors","technology","identification","particles","distinguish","descriptor","reconstructing","characterizes","segmentation","presented","neighbourhood","projection","potential","excellent","amplitude","redundant","augmented","classical","concatenated","approaches","framelets","generalize","condition","behaviors","discovery","significant","unpooling","nonlinearity","components","shrinkage","originally","demonstrated","developed","convolving","multilayer","processing","consistent","convolution","architectures","numerical","understood","balancing","reasoning","available","particularly","exploitation","interesting","understanding","successful","technique","replicate","analytically","properties","empirically","independent","adversarial","exploration","enhancing","computational","cognitive","impossible","highlights","unprecedented","principles","robustness","demanding","introduction","introduces","elementary","phenomena","subcategories","dirichlet","previously","documents","parametric","researchers","benchmarks","nonparametric","dependence","inference","variational","hierar ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	underestimation
# 	semiparametric
# 	emphmulti
# 	photovoltaic
# 	prioritization
# 	certificate
# 	transports
# 	defensive
# 	parametrically
# 	thermostats
# 	decouples
# 	offerings
# 	layerwise
# 	parameterizes
# 	superhuman
# 	hamiltonians
# 	discretizing
# 	censoring
# 	exposition
# 	fmathcalx
# Some words which never appear in Statistics papers:
# 	transactions
# 	truthfully
# 	semantical
# 	computerized
# 	constriction
# 	capacities
# 	participating
# 	inputting
# 	inconvenient
# 	annotating
# 	forwarding
# 	formalisation
# 	readiness
# 	transducers
# 	steerable
# 	isotropic
# 	reusability
# 	syntactic
# 	ventricular
# 	intraclass

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.069556142181841e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7566666666666667
